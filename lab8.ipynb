# %%
import numpy as np
import matplotlib.pyplot as plt
import time
import mkl

mkl.set_num_threads(4)
np.random.seed(1234)

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams["figure.figsize"] = [16, 9]

# %% [markdown]
# ### Handy utility functions

# %%
def append_ones(matrix, axis=1):
    return np.concatenate((matrix, np.ones((matrix.shape[0], 1), dtype=np.float32)), axis=axis)

def zeros(*dims):
    return np.zeros(shape=tuple(dims), dtype=np.float32)

def ones(*dims):
    return np.ones(shape=tuple(dims), dtype=np.float32)

def rand(*dims):
    return np.random.rand(*dims).astype(np.float32)

def randn(*dims):
    return np.random.randn(*dims).astype(np.float32)

def chunks(seq, size):
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

def as_matrix(vector):
    return np.reshape(vector, (-1, 1))

def one_hot_encode(labels):
    one_hot = zeros(labels.shape[0], np.max(labels) + 1) 
    one_hot[np.arange(labels.shape[0]), labels] = 1
    return one_hot.astype(np.float32)

def classify(mlp, batch):
    probabilities = forward_pass(mlp, batch, False)
    return np.argmax(probabilities, axis=1)

def tiles(examples):
    rows_count = examples.shape[0]
    cols_count = examples.shape[1]
    tile_height = examples.shape[2]
    tile_width = examples.shape[3]
    
    space_between_tiles = 2
    img_matrix = np.empty(shape=(rows_count * (tile_height + space_between_tiles) - space_between_tiles,  
                                 cols_count * (tile_width + space_between_tiles) - space_between_tiles))
    img_matrix.fill(np.nan)

    for r in range(rows_count):
        for c in range(cols_count):
            x_0 = r * (tile_height + space_between_tiles)
            y_0 = c * (tile_width + space_between_tiles)
            ex_min = np.min(examples[r, c])
            ex_max = np.max(examples[r, c])
            img_matrix[x_0:x_0 + tile_height, y_0:y_0 + tile_width] = (examples[r, c] - ex_min) / (ex_max - ex_min)
    
    plt.matshow(img_matrix, cmap='gray', interpolation='none')
    plt.axis('off')
    plt.show()

def draw_rbm_filters(rbm):
    filters = np.reshape(np.transpose(rbm.W)[:-1, :-1], newshape=(8, -1, 28, 28))
    tiles(filters)

def draw_layer_filters(layer):
    filters = np.reshape(layer.W[:-1].T, newshape=(8, -1, 28, 28))
    tiles(filters)

# %% [markdown]
# ### Activation functions

# %%
def sigmoid(batch, stochastic=False):
    activations = 1.0 / (1.0 + np.exp(-batch))
    if stochastic:
        return activations > rand(*activations.shape).astype(np.float32)
    else:
        return activations

def sigmoid_derivative(batch):
    s = sigmoid(batch)
    return s * (1.0 - s)

def softmax(batch):
    argmaxs = np.argmax(batch, axis=1)
    maxs = np.choose(argmaxs, batch.T)
    normalized = (batch.T - maxs).T
    return (np.exp(normalized).T/np.sum(np.exp(normalized), axis=1)).T

# %% [markdown]
# # MNIST dataset

# %%
import mnist
digits = np.reshape(mnist.train_images()[:12*24], newshape=(12, 24, 28, 28))
tiles(digits)

# %% [markdown]
# # ReLU and Max-Norm regularization

# %%
def relu(batch, stochastic=False):
    if stochastic == True:
        return batch*(1.0*(batch>0).reshape(batch.shape)) + np.random.normal(0, np.sqrt(sigmoid(batch)))
    else:
        return batch*(1.0*(batch>0).reshape(batch.shape))
        
def relu_derivative(batch):
    return 1.0*(batch>0).reshape(batch.shape)

# %%
def limit_weights(weights, limit):
    norms = np.linalg.norm(weights, axis=0, keepdims=True)
    return weights*np.where(norms <= limit, 1, limit/norms)

# %% [markdown]
# # RBM & DBN training

# %%
class Rbm:
    def __init__(self, visible_size, hidden_size, visible_act_func, hidden_act_func, 
                 learning_rate, momentum, weight_limit):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.visible_act_func = visible_act_func
        self.hidden_act_func = hidden_act_func
        
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.weight_limit = weight_limit
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size+1)).astype(np.float32)
        self.W[:, -1] = 0.0
        self.W[-1, :] = 0.0
        self.M = zeros(self.visible_size+1, self.hidden_size+1)

# %%
def cdk(rbm, minibatch, k=1):
    observations_count = minibatch.shape[0]

    positive_visible = minibatch
    negative_visible = append_ones(zeros(observations_count, rbm.visible_size))

    positive_hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    negative_hidden = append_ones(zeros(observations_count, rbm.hidden_size))

    z = minibatch @ rbm.W[:, :-1]
    positive_hidden[:, :-1] = rbm.hidden_act_func(z)
    negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)

    for cd_i in range(k):
        negative_visible[:, :-1] = rbm.visible_act_func(negative_hidden @ rbm.W[:-1, :].T,
                                                        stochastic=True)
        z = negative_visible @ rbm.W[:, :-1]
        if cd_i < (k - 1):
            negative_hidden[:, :-1] = rbm.hidden_act_func(z, stochastic=True)
        else:
            negative_hidden[:, :-1] = rbm.hidden_act_func(z)

    rbm.M *= rbm.momentum
    rbm.M += (rbm.learning_rate / observations_count) * positive_visible.T @ positive_hidden
    rbm.M -= (rbm.learning_rate / observations_count) * negative_visible.T @ negative_hidden

    rbm.W += rbm.M;
    
    if rbm.weight_limit > 0.0:
        rbm.W[:-1, :-1] = limit_weights(rbm.W[:-1, :-1], rbm.weight_limit)

def reconstuction_error(rbm, minibatch):
    observations_count = minibatch.shape[0]
    visible = zeros(observations_count, rbm.visible_size)
    hidden = append_ones(zeros(observations_count, rbm.hidden_size))
    
    hidden[:, :-1] =  rbm.hidden_act_func(minibatch @ rbm.W[:, :-1], stochastic=True)
    visible = rbm.visible_act_func(hidden @ np.transpose(rbm.W[:-1, :]))
    
    error = minibatch[:, :-1] - visible
    error = np.sum(np.square(error)) / observations_count
    
    return error

# %%
def propagate_up(dbn, layers_count, visible):
    for i in range(layers_count):
        visible = append_ones(sigmoid(visible @ dbn[i].W[:, :-1]))
    return visible

def propagate_down(dbn, layers_count, hidden):
    for i in reversed(range(layers_count)):
        hidden = append_ones(sigmoid(hidden @ np.transpose(dbn[i].W[:-1, :])))
    return hidden

def dbn_reconstuction_error(dbn, layer_idx, minibatch):
    propagated = propagate_up(dbn, layer_idx, minibatch)
    return reconstuction_error(dbn[layer_idx], propagated)

def train_dbn_layer(dbn, layer_idx, dataset, batch_size):
    dataset = propagate_up(dbn, layer_idx, dataset)
    
    batches_limit = dataset.shape[0] / batch_size
    for batch_idx, batch in enumerate(chunks(dataset, batch_size)):
        cdk(dbn[layer_idx], batch)
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")
            
def run_dbn_training(dbn, dataset, monitoring_set, batch_size, epochs_count, target_momentum=0.9):
    for layer_idx in range(len(dbn)):
        print("\nLearning layer {}".format(layer_idx+1))

        for epoch in range(epochs_count):
            print("Epoch {}:".format(epoch+1),  end="\t")

            if epoch == 5:
                dbn[layer_idx].momentum = target_momentum

            start_time = time.time()
            train_dbn_layer(dbn, layer_idx, dataset, batch_size)
            elapsed = time.time() - start_time

            error = dbn_reconstuction_error(dbn, layer_idx, monitoring_set)
            print("\telapsed: {0:>2.2f}s, reconstruction error: {1:>2.2f}".format(elapsed, error))

# %% [markdown]
# # MLP training

# %%
class Layer:
    def __init__(self, visible_size, hidden_size, activation_fun, d_activation_fun, 
                 learning_rate, momentum, weight_limit):
        self.visible_size = visible_size
        self.hidden_size = hidden_size
        
        self.activation_fun = activation_fun
        self.d_activation_fun = d_activation_fun
                
        self.learning_rate = learning_rate
        self.momentum = momentum
        
        self.weight_limit = weight_limit
        
        self.reset()
    
    def reset(self):
        self.W = np.random.normal(scale=0.01, size=(self.visible_size+1, self.hidden_size)).astype(np.float32)
        self.W[-1, :] = 0.0
        
        self.activations = None
        self.d_activations = None
        self.deltas = None

        self.M = zeros(self.visible_size+1, self.hidden_size)

# %% [markdown]
# ### Forward pass

# %%
def forward_pass(mlp, batch, compute_derivatives):
    visible = batch
    
    for layer_idx, layer in enumerate(mlp):
        z = visible@layer.W
        layer.activations = append_ones(layer.activation_fun(z))
        
        if compute_derivatives and (layer_idx < len(mlp) - 1):
            layer.d_activations = layer.d_activation_fun(z)
        
        visible = layer.activations
        
    return visible[:, :-1]

# %% [markdown]
# ### Error backpropagation

# %%
def error_backpropagate(mlp, batch):
    observations_count = batch.shape[0]
    
    for layer_idx, layer in reversed(list(enumerate(mlp))):
        if layer_idx > 0:
            prev_layer = mlp[layer_idx - 1]
            visible = prev_layer.activations
            
            prev_layer.deltas = (layer.deltas@layer.W[:-1,:].T)*prev_layer.d_activations
        else:
            visible = batch
        
        layer.M = layer.momentum*layer.M - layer.learning_rate*((visible.T@layer.deltas)/observations_count)    
        layer.W += layer.M
        
        if layer.weight_limit > 0.0:
            layer.W[:-1, :] = limit_weights(layer.W[:-1, :], layer.weight_limit)

# %% [markdown]
# ### Training procedure

# %%
def train_mlp(mlp, dataset, labels, batch_size):
    batches_limit = dataset.shape[0] / batch_size
    
    batched_data = chunks(dataset, batch_size)
    batched_labels = chunks(labels, batch_size)
    
    for batch_idx, (batch, batch_labels) in enumerate(zip(batched_data, batched_labels)):
        y = forward_pass(mlp, batch, True)
        
        mlp[-1].deltas = y - batch_labels
        
        error_backpropagate(mlp, batch)
        
        if batch_idx % round(batches_limit / 40) == 0: print("#", end="")

# %%
def run_mlp_training(mlp, train_set, train_labels, validation_set, validation_labels,
                     batch_size, epochs_count, target_momentum=0.95):
    for epoch in range(epochs_count):
        print("Epoch {}:".format(epoch+1),  end="\t")
        
        if epoch == 5:
            for layer in mlp: layer.momentum = target_momentum
        
        start_time = time.time()
        train_mlp(mlp, train_set, train_labels, batch_size)
        elapsed = time.time() - start_time

        predictions = classify(mlp, validation_set)
        accuracy = 100.0 * np.sum(predictions == validation_labels) / predictions.shape[0]
        print("\telapsed: {0:>2.2f}s, accuracy: {1:>2.2f}".format(elapsed, accuracy))

    print("Training finished!")

# %% [markdown]
# #  Initializing MLP with DBN weights
#
# Implement initialization of MLP weights (and biases) using weights (and biases) from the DBN layers.
#
# Make sure that the MLP weights (and biases) are **copies** of the DBN weights (and biases). You can use ```np.copy(...)``` function to copy the weights (simple assignment will make a view instead of a copy).

# %%
def initialize_mlp(mlp, dbn):
    for (i,l) in enumerate(dbn):
        mlp[i].W[:,:] = l.W[:,:-1]

# %% [markdown]
# # MNIST digits classification

# %%
DATASET_SIZE = 10000 # 60000 for whole dataset
DIGIT_SIZE = 28

##### Train set #####

mnist_train_images = mnist.train_images().astype(np.float32) / 255.0
mnist_train_labels = mnist.train_labels()

order = np.random.permutation(len(mnist_train_images))
mnist_train_images = mnist_train_images[order]
mnist_train_labels = mnist_train_labels[order]

mnist_train_images = np.reshape(mnist_train_images[:DATASET_SIZE],
                                newshape=(DATASET_SIZE, DIGIT_SIZE*DIGIT_SIZE))
mnist_train_images = append_ones(mnist_train_images)

mnist_train_labels = mnist_train_labels[:DATASET_SIZE]
mnist_train_labels = one_hot_encode(mnist_train_labels)

monitoring_set_indeces = np.random.choice(mnist_train_images.shape[0], 512, replace=False)
monitoring_set = mnist_train_images[monitoring_set_indeces]

##### Test set #####

mnist_test_images = mnist.test_images().astype(np.float32) / 255.0
mnist_test_images = np.reshape(mnist_test_images, newshape=(-1, DIGIT_SIZE*DIGIT_SIZE))
mnist_test_images = append_ones(mnist_test_images)

mnist_test_labels = mnist.test_labels()

# %%
VISIBLE_LAYER_SIZE = DIGIT_SIZE*DIGIT_SIZE
HIDDEN_LAYER_SIZE = 256

BATCH_SIZE = 128
EPOCHS_COUNT = 50

MLP_LEARNING_RATE = 0.03
SOFTMAX_LEARNING_RATE = 0.15
RBM_LEARNING_RATE = 0.003
MOMENTUM = 0.5

# %% [markdown]
# ### Plain vs pretrained comparison

# %%
from IPython.core.display import HTML

def compare_pretraining_results(mlp, dbn,
                                train_set, train_labels,
                                validation_set, validation_labels,
                                monitoring_set,
                                batch_size, epochs_count):
    for layer in mlp:
        layer.reset()

    display(HTML('<h3>Plain MLP training</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)
    
    display(HTML('<h3>Input layer filters in the plain MLP</h3>'))
    draw_layer_filters(mlp[0])
    
    display(HTML('<h3>Largest norms of weight-vectors in the plain MLP layers</h3>'))
    for i, layer in enumerate(mlp):
        max_norm = np.max(np.linalg.norm(layer.W[:-1, :], axis=0))
        print('\tlayer {0}: {1:.2f}'.format(i+1, max_norm))
    
    display(HTML('<h3>DBN training</h3>'))
    run_dbn_training(dbn, train_set, monitoring_set, batch_size, epochs_count)
    
    for layer in mlp:
        layer.reset()
    
    initialize_mlp(mlp, dbn)
    
    display(HTML('<h3>Finetuning pretrained MLP</h3>'))
    run_mlp_training(mlp,
                     train_set, train_labels,
                     validation_set, validation_labels,
                     batch_size, epochs_count)
    
    display(HTML('<h3>First layer filters in the DBN</h3>'))
    draw_rbm_filters(dbn[0])
    
    display(HTML('<h3>Input layer filters in the pretrained & finetuned MLP</h3>'))
    draw_layer_filters(mlp[0])

    display(HTML('<h3>Largest norms of weight-vectors in the finetuned MLP layers</h3>'))
    for i, layer in enumerate(mlp):
        max_norm = np.max(np.linalg.norm(layer.W[:-1, :], axis=0))
        print('\tlayer {0}: {1:.2f}'.format(i+1, max_norm))

# %% [markdown]
# ### Shallow ReLU network

# %%
shallow_mlp = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=2.0),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=1.0),
    Layer(HIDDEN_LAYER_SIZE, 10, softmax, None, SOFTMAX_LEARNING_RATE, MOMENTUM,
          weight_limit=4.0)
]

shallow_dbn = [
    Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=2.0),
    Rbm(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=1.0)
]

compare_pretraining_results(shallow_mlp, shallow_dbn,
                            mnist_train_images, mnist_train_labels,
                            mnist_test_images, mnist_test_labels,
                            monitoring_set,
                            BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>Plain MLP training</h3>
# Epoch 1:	########################################	elapsed: 1.03s, accuracy: 11.35
# Epoch 2:	########################################	elapsed: 1.01s, accuracy: 48.14
# Epoch 3:	########################################	elapsed: 0.99s, accuracy: 67.03
# Epoch 4:	########################################	elapsed: 0.95s, accuracy: 76.89
# Epoch 5:	########################################	elapsed: 0.94s, accuracy: 81.72
# Epoch 6:	########################################	elapsed: 0.94s, accuracy: 90.00
# Epoch 7:	########################################	elapsed: 0.95s, accuracy: 92.18
# Epoch 8:	########################################	elapsed: 0.95s, accuracy: 92.93
# Epoch 9:	########################################	elapsed: 0.94s, accuracy: 93.29
# Epoch 10:	########################################	elapsed: 0.96s, accuracy: 93.59
# Epoch 11:	########################################	elapsed: 0.94s, accuracy: 94.53
# Epoch 12:	########################################	elapsed: 0.95s, accuracy: 95.03
# Epoch 13:	########################################	elapsed: 0.94s, accuracy: 95.33
# Epoch 14:	########################################	elapsed: 0.93s, accuracy: 95.14
# Epoch 15:	########################################	elapsed: 0.92s, accuracy: 95.11
# Epoch 16:	########################################	elapsed: 0.96s, accuracy: 94.52
# Epoch 17:	########################################	elapsed: 0.94s, accuracy: 95.91
# Epoch 18:	########################################	elapsed: 0.95s, accuracy: 96.21
# Epoch 19:	########################################	elapsed: 0.93s, accuracy: 95.78
# Epoch 20:	########################################	elapsed: 0.93s, accuracy: 95.45
# Epoch 21:	########################################	elapsed: 0.93s, accuracy: 95.42
# Epoch 22:	########################################	elapsed: 0.94s, accuracy: 96.54
# Epoch 23:	########################################	elapsed: 0.92s, accuracy: 96.45
# Epoch 24:	########################################	elapsed: 0.94s, accuracy: 96.60
# Epoch 25:	########################################	elapsed: 0.93s, accuracy: 96.91
# Epoch 26:	########################################	elapsed: 0.94s, accuracy: 96.90
# Epoch 27:	########################################	elapsed: 0.93s, accuracy: 96.95
# Epoch 28:	########################################	elapsed: 0.93s, accuracy: 96.94
# Epoch 29:	########################################	elapsed: 0.93s, accuracy: 96.95
# Epoch 30:	########################################	elapsed: 0.91s, accuracy: 96.94
# Epoch 31:	########################################	elapsed: 0.93s, accuracy: 96.95
# Epoch 32:	########################################	elapsed: 0.96s, accuracy: 96.96
# Epoch 33:	########################################	elapsed: 0.95s, accuracy: 96.96
# Epoch 34:	########################################	elapsed: 0.95s, accuracy: 96.98
# Epoch 35:	########################################	elapsed: 0.97s, accuracy: 97.02
# Epoch 36:	########################################	elapsed: 0.97s, accuracy: 97.02
# Epoch 37:	########################################	elapsed: 1.00s, accuracy: 97.03
# Epoch 38:	########################################	elapsed: 1.00s, accuracy: 97.03
# Epoch 39:	########################################	elapsed: 1.03s, accuracy: 97.04
# Epoch 40:	########################################	elapsed: 1.00s, accuracy: 97.04
# Epoch 41:	########################################	elapsed: 0.98s, accuracy: 97.04
# Epoch 42:	########################################	elapsed: 0.96s, accuracy: 97.04
# Epoch 43:	########################################	elapsed: 0.98s, accuracy: 97.04
# Epoch 44:	########################################	elapsed: 0.97s, accuracy: 97.06
# Epoch 45:	########################################	elapsed: 0.98s, accuracy: 97.07
# Epoch 46:	########################################	elapsed: 0.97s, accuracy: 97.07
# Epoch 47:	########################################	elapsed: 0.96s, accuracy: 97.07
# Epoch 48:	########################################	elapsed: 0.94s, accuracy: 97.06
# Epoch 49:	########################################	elapsed: 0.92s, accuracy: 97.06
# Epoch 50:	########################################	elapsed: 1.37s, accuracy: 97.06
# Training finished!
# <h3>Input layer filters in the plain MLP</h3>
# <h3>Largest norms of weight-vectors in the plain MLP layers</h3>
# 	layer 1: 2.00
# 	layer 2: 1.00
# 	layer 3: 4.00
# <h3>DBN training</h3>
# Learning layer 1
# Epoch 1:	########################################	elapsed: 1.10s, reconstruction error: 79.68
# Epoch 2:	########################################	elapsed: 0.93s, reconstruction error: 57.20
# Epoch 3:	########################################	elapsed: 0.94s, reconstruction error: 44.22
# Epoch 4:	########################################	elapsed: 1.03s, reconstruction error: 37.78
# Epoch 5:	########################################	elapsed: 0.92s, reconstruction error: 33.81
# Epoch 6:	########################################	elapsed: 0.91s, reconstruction error: 25.69
# Epoch 7:	########################################	elapsed: 0.91s, reconstruction error: 21.79
# Epoch 8:	########################################	elapsed: 0.92s, reconstruction error: 19.46
# Epoch 9:	########################################	elapsed: 0.94s, reconstruction error: 17.84
# Epoch 10:	########################################	elapsed: 0.92s, reconstruction error: 16.63
# Epoch 11:	########################################	elapsed: 1.07s, reconstruction error: 15.50
# Epoch 12:	########################################	elapsed: 1.06s, reconstruction error: 14.63
# Epoch 13:	########################################	elapsed: 1.02s, reconstruction error: 13.88
# Epoch 14:	########################################	elapsed: 1.05s, reconstruction error: 13.32
# Epoch 15:	########################################	elapsed: 1.07s, reconstruction error: 12.73
# Epoch 16:	########################################	elapsed: 1.14s, reconstruction error: 12.43
# Epoch 17:	########################################	elapsed: 1.07s, reconstruction error: 11.81
# Epoch 18:	########################################	elapsed: 1.04s, reconstruction error: 11.60
# Epoch 19:	########################################	elapsed: 1.07s, reconstruction error: 11.34
# Epoch 20:	########################################	elapsed: 1.08s, reconstruction error: 11.15
# Epoch 21:	########################################	elapsed: 1.07s, reconstruction error: 10.84
# Epoch 22:	########################################	elapsed: 1.07s, reconstruction error: 10.62
# Epoch 23:	########################################	elapsed: 1.10s, reconstruction error: 10.52
# Epoch 24:	########################################	elapsed: 1.13s, reconstruction error: 10.31
# Epoch 25:	########################################	elapsed: 1.07s, reconstruction error: 9.95
# Epoch 26:	########################################	elapsed: 1.01s, reconstruction error: 9.94
# Epoch 27:	########################################	elapsed: 1.00s, reconstruction error: 9.84
# Epoch 28:	########################################	elapsed: 1.23s, reconstruction error: 9.90
# Epoch 29:	########################################	elapsed: 1.02s, reconstruction error: 9.78
# Epoch 30:	########################################	elapsed: 1.00s, reconstruction error: 9.72
# Epoch 31:	########################################	elapsed: 1.03s, reconstruction error: 9.61
# Epoch 32:	########################################	elapsed: 1.01s, reconstruction error: 9.59
# Epoch 33:	########################################	elapsed: 1.02s, reconstruction error: 9.56
# Epoch 34:	########################################	elapsed: 0.99s, reconstruction error: 9.51
# Epoch 35:	########################################	elapsed: 0.99s, reconstruction error: 9.48
# Epoch 36:	########################################	elapsed: 1.00s, reconstruction error: 9.32
# Epoch 37:	########################################	elapsed: 1.04s, reconstruction error: 9.32
# Epoch 38:	########################################	elapsed: 1.07s, reconstruction error: 9.34
# Epoch 39:	########################################	elapsed: 1.08s, reconstruction error: 9.34
# Epoch 40:	########################################	elapsed: 1.08s, reconstruction error: 9.22
# Epoch 41:	########################################	elapsed: 1.08s, reconstruction error: 9.27
# Epoch 42:	########################################	elapsed: 1.09s, reconstruction error: 9.30
# Epoch 43:	########################################	elapsed: 1.09s, reconstruction error: 9.15
# Epoch 44:	########################################	elapsed: 1.08s, reconstruction error: 9.05
# Epoch 45:	########################################	elapsed: 1.08s, reconstruction error: 9.04
# Epoch 46:	########################################	elapsed: 1.13s, reconstruction error: 9.10
# Epoch 47:	########################################	elapsed: 1.15s, reconstruction error: 9.06
# Epoch 48:	########################################	elapsed: 1.12s, reconstruction error: 9.06
# Epoch 49:	########################################	elapsed: 1.18s, reconstruction error: 8.94
# Epoch 50:	########################################	elapsed: 1.15s, reconstruction error: 8.94
#
# Learning layer 2
# Epoch 1:	########################################	elapsed: 0.97s, reconstruction error: 20.25
# Epoch 2:	########################################	elapsed: 1.05s, reconstruction error: 19.37
# Epoch 3:	########################################	elapsed: 0.91s, reconstruction error: 17.42
# Epoch 4:	########################################	elapsed: 0.92s, reconstruction error: 16.09
# Epoch 5:	########################################	elapsed: 0.95s, reconstruction error: 15.73
# Epoch 6:	########################################	elapsed: 1.07s, reconstruction error: 16.70
# Epoch 7:	########################################	elapsed: 0.89s, reconstruction error: 16.02
# Epoch 8:	########################################	elapsed: 0.83s, reconstruction error: 15.19
# Epoch 9:	########################################	elapsed: 0.83s, reconstruction error: 15.29
# Epoch 10:	########################################	elapsed: 0.83s, reconstruction error: 15.08
# Epoch 11:	########################################	elapsed: 0.84s, reconstruction error: 15.25
# Epoch 12:	########################################	elapsed: 0.98s, reconstruction error: 14.95
# Epoch 13:	########################################	elapsed: 0.84s, reconstruction error: 15.14
# Epoch 14:	########################################	elapsed: 0.91s, reconstruction error: 15.13
# Epoch 15:	########################################	elapsed: 0.88s, reconstruction error: 14.97
# Epoch 16:	########################################	elapsed: 0.87s, reconstruction error: 15.06
# Epoch 17:	########################################	elapsed: 0.91s, reconstruction error: 15.16
# Epoch 18:	########################################	elapsed: 0.90s, reconstruction error: 14.99
# Epoch 19:	########################################	elapsed: 0.92s, reconstruction error: 15.21
# Epoch 20:	########################################	elapsed: 0.92s, reconstruction error: 15.05
# Epoch 21:	########################################	elapsed: 0.90s, reconstruction error: 14.91
# Epoch 22:	########################################	elapsed: 0.91s, reconstruction error: 14.84
# Epoch 23:	########################################	elapsed: 0.96s, reconstruction error: 14.97
# Epoch 24:	########################################	elapsed: 0.97s, reconstruction error: 14.89
# Epoch 25:	########################################	elapsed: 0.96s, reconstruction error: 15.02
# Epoch 26:	########################################	elapsed: 0.96s, reconstruction error: 14.83
# Epoch 27:	########################################	elapsed: 0.94s, reconstruction error: 15.17
# Epoch 28:	########################################	elapsed: 0.95s, reconstruction error: 14.52
# Epoch 29:	########################################	elapsed: 0.95s, reconstruction error: 14.73
# Epoch 30:	########################################	elapsed: 0.94s, reconstruction error: 14.98
# Epoch 31:	########################################	elapsed: 1.04s, reconstruction error: 14.90
# Epoch 32:	########################################	elapsed: 0.92s, reconstruction error: 14.84
# Epoch 33:	########################################	elapsed: 0.91s, reconstruction error: 14.84
# Epoch 34:	########################################	elapsed: 0.90s, reconstruction error: 14.83
# Epoch 35:	########################################	elapsed: 0.91s, reconstruction error: 14.98
# Epoch 36:	########################################	elapsed: 0.91s, reconstruction error: 15.20
# Epoch 37:	########################################	elapsed: 0.90s, reconstruction error: 14.83
# Epoch 38:	########################################	elapsed: 0.92s, reconstruction error: 15.29
# Epoch 39:	########################################	elapsed: 0.94s, reconstruction error: 14.95
# Epoch 40:	########################################	elapsed: 0.93s, reconstruction error: 15.60
# Epoch 41:	########################################	elapsed: 0.93s, reconstruction error: 14.70
# Epoch 42:	########################################	elapsed: 0.92s, reconstruction error: 15.18
# Epoch 43:	########################################	elapsed: 0.93s, reconstruction error: 15.00
# Epoch 44:	########################################	elapsed: 0.93s, reconstruction error: 15.07
# Epoch 45:	########################################	elapsed: 0.94s, reconstruction error: 14.87
# Epoch 46:	########################################	elapsed: 0.92s, reconstruction error: 15.16
# Epoch 47:	########################################	elapsed: 0.92s, reconstruction error: 15.38
# Epoch 48:	########################################	elapsed: 0.92s, reconstruction error: 15.29
# Epoch 49:	########################################	elapsed: 0.92s, reconstruction error: 15.30
# Epoch 50:	########################################	elapsed: 0.93s, reconstruction error: 15.30
# <h3>Finetuning pretrained MLP</h3>
# Epoch 1:	########################################	elapsed: 0.97s, accuracy: 90.29
# Epoch 2:	########################################	elapsed: 0.96s, accuracy: 94.40
# Epoch 3:	########################################	elapsed: 0.96s, accuracy: 94.88
# Epoch 4:	########################################	elapsed: 0.97s, accuracy: 94.98
# Epoch 5:	########################################	elapsed: 0.95s, accuracy: 94.55
# Epoch 6:	########################################	elapsed: 0.93s, accuracy: 95.65
# Epoch 7:	########################################	elapsed: 0.97s, accuracy: 96.16
# Epoch 8:	########################################	elapsed: 0.97s, accuracy: 96.45
# Epoch 9:	########################################	elapsed: 0.98s, accuracy: 95.65
# Epoch 10:	########################################	elapsed: 0.95s, accuracy: 95.92
# Epoch 11:	########################################	elapsed: 0.98s, accuracy: 96.70
# Epoch 12:	########################################	elapsed: 1.07s, accuracy: 96.69
# Epoch 13:	########################################	elapsed: 0.97s, accuracy: 96.66
# Epoch 14:	########################################	elapsed: 0.95s, accuracy: 97.04
# Epoch 15:	########################################	elapsed: 0.96s, accuracy: 97.15
# Epoch 16:	########################################	elapsed: 1.01s, accuracy: 97.11
# Epoch 17:	########################################	elapsed: 1.00s, accuracy: 97.28
# Epoch 18:	########################################	elapsed: 0.93s, accuracy: 97.18
# Epoch 19:	########################################	elapsed: 0.95s, accuracy: 97.16
# Epoch 20:	########################################	elapsed: 1.02s, accuracy: 97.21
# Epoch 21:	########################################	elapsed: 0.94s, accuracy: 97.28
# Epoch 22:	########################################	elapsed: 0.92s, accuracy: 97.26
# Epoch 23:	########################################	elapsed: 0.92s, accuracy: 97.27
# Epoch 24:	########################################	elapsed: 0.93s, accuracy: 97.26
# Epoch 25:	########################################	elapsed: 0.92s, accuracy: 97.26
# Epoch 26:	########################################	elapsed: 0.93s, accuracy: 97.28
# Epoch 27:	########################################	elapsed: 0.94s, accuracy: 97.29
# Epoch 28:	########################################	elapsed: 0.96s, accuracy: 97.27
# Epoch 29:	########################################	elapsed: 0.93s, accuracy: 97.29
# Epoch 30:	########################################	elapsed: 1.01s, accuracy: 97.32
# Epoch 31:	########################################	elapsed: 0.99s, accuracy: 97.32
# Epoch 32:	########################################	elapsed: 0.98s, accuracy: 97.32
# Epoch 33:	########################################	elapsed: 0.98s, accuracy: 97.30
# Epoch 34:	########################################	elapsed: 0.98s, accuracy: 97.31
# Epoch 35:	########################################	elapsed: 0.98s, accuracy: 97.30
# Epoch 36:	########################################	elapsed: 0.98s, accuracy: 97.29
# Epoch 37:	########################################	elapsed: 0.95s, accuracy: 97.29
# Epoch 38:	########################################	elapsed: 0.95s, accuracy: 97.29
# Epoch 39:	########################################	elapsed: 0.94s, accuracy: 97.31
# Epoch 40:	########################################	elapsed: 0.92s, accuracy: 97.30
# Epoch 41:	########################################	elapsed: 0.95s, accuracy: 97.30
# Epoch 42:	########################################	elapsed: 0.95s, accuracy: 97.32
# Epoch 43:	########################################	elapsed: 0.94s, accuracy: 97.31
# Epoch 44:	########################################	elapsed: 0.96s, accuracy: 97.31
# Epoch 45:	########################################	elapsed: 0.96s, accuracy: 97.31
# Epoch 46:	########################################	elapsed: 0.99s, accuracy: 97.31
# Epoch 47:	########################################	elapsed: 1.04s, accuracy: 97.31
# Epoch 48:	########################################	elapsed: 0.97s, accuracy: 97.31
# Epoch 49:	########################################	elapsed: 0.93s, accuracy: 97.30
# Epoch 50:	########################################	elapsed: 0.94s, accuracy: 97.32
# Training finished!
# <h3>First layer filters in the DBN</h3>
# <h3>Input layer filters in the pretrained & finetuned MLP</h3>
# <h3>Largest norms of weight-vectors in the finetuned MLP layers</h3>
# 	layer 1: 2.00
# 	layer 2: 1.00
# 	layer 3: 4.00

# %% [markdown]
# ### Deep ReLU network

# %%
deep_mlp = [
    Layer(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=2.0),
    Layer(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=1.0),
    Layer(HIDDEN_LAYER_SIZE, 2 * HIDDEN_LAYER_SIZE, relu, relu_derivative, MLP_LEARNING_RATE, MOMENTUM,
          weight_limit=1.0),
    Layer(2 * HIDDEN_LAYER_SIZE, 10, softmax, None, SOFTMAX_LEARNING_RATE, MOMENTUM,
          weight_limit=4.0)
]

deep_dbn = [
    Rbm(VISIBLE_LAYER_SIZE, HIDDEN_LAYER_SIZE, sigmoid, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=2.0),
    Rbm(HIDDEN_LAYER_SIZE, HIDDEN_LAYER_SIZE, relu, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=1.0),
    Rbm(HIDDEN_LAYER_SIZE, 2 * HIDDEN_LAYER_SIZE, relu, relu, RBM_LEARNING_RATE, MOMENTUM,
        weight_limit=1.0)
]

compare_pretraining_results(deep_mlp, deep_dbn,
                            mnist_train_images, mnist_train_labels,
                            mnist_test_images, mnist_test_labels,
                            monitoring_set,
                            BATCH_SIZE, EPOCHS_COUNT)
# Out:
# <h3>Plain MLP training</h3>
# Epoch 1:	########################################	elapsed: 1.65s, accuracy: 11.35
# Epoch 2:	########################################	elapsed: 1.57s, accuracy: 11.35
# Epoch 3:	########################################	elapsed: 1.56s, accuracy: 11.35
# Epoch 4:	########################################	elapsed: 1.61s, accuracy: 11.35
# Epoch 5:	########################################	elapsed: 1.61s, accuracy: 11.35
# Epoch 6:	########################################	elapsed: 1.67s, accuracy: 45.87
# Epoch 7:	########################################	elapsed: 1.67s, accuracy: 82.27
# Epoch 8:	########################################	elapsed: 1.56s, accuracy: 88.21
# Epoch 9:	########################################	elapsed: 1.55s, accuracy: 92.47
# Epoch 10:	########################################	elapsed: 1.58s, accuracy: 92.24
# Epoch 11:	########################################	elapsed: 1.57s, accuracy: 92.60
# Epoch 12:	########################################	elapsed: 1.59s, accuracy: 93.92
# Epoch 13:	########################################	elapsed: 1.57s, accuracy: 93.63
# Epoch 14:	########################################	elapsed: 1.59s, accuracy: 94.08
# Epoch 15:	########################################	elapsed: 1.56s, accuracy: 93.43
# Epoch 16:	########################################	elapsed: 1.57s, accuracy: 94.45
# Epoch 17:	########################################	elapsed: 1.70s, accuracy: 94.05
# Epoch 18:	########################################	elapsed: 1.55s, accuracy: 95.52
# Epoch 19:	########################################	elapsed: 1.50s, accuracy: 95.40
# Epoch 20:	########################################	elapsed: 1.47s, accuracy: 95.58
# Epoch 21:	########################################	elapsed: 1.68s, accuracy: 95.49
# Epoch 22:	########################################	elapsed: 1.90s, accuracy: 95.23
# Epoch 23:	########################################	elapsed: 1.59s, accuracy: 95.58
# Epoch 24:	########################################	elapsed: 1.58s, accuracy: 95.85
# Epoch 25:	########################################	elapsed: 1.89s, accuracy: 96.10
# Epoch 26:	########################################	elapsed: 1.60s, accuracy: 96.03
# Epoch 27:	########################################	elapsed: 1.57s, accuracy: 96.20
# Epoch 28:	########################################	elapsed: 1.61s, accuracy: 96.28
# Epoch 29:	########################################	elapsed: 1.60s, accuracy: 96.27
# Epoch 30:	########################################	elapsed: 1.58s, accuracy: 96.47
# Epoch 31:	########################################	elapsed: 1.56s, accuracy: 96.54
# Epoch 32:	########################################	elapsed: 1.56s, accuracy: 96.53
# Epoch 33:	########################################	elapsed: 1.58s, accuracy: 96.52
# Epoch 34:	########################################	elapsed: 1.56s, accuracy: 96.52
# Epoch 35:	########################################	elapsed: 1.56s, accuracy: 96.51
# Epoch 36:	########################################	elapsed: 1.57s, accuracy: 96.49
# Epoch 37:	########################################	elapsed: 1.56s, accuracy: 96.49
# Epoch 38:	########################################	elapsed: 1.75s, accuracy: 96.48
# Epoch 39:	########################################	elapsed: 1.58s, accuracy: 96.49
# Epoch 40:	########################################	elapsed: 1.59s, accuracy: 96.49
# Epoch 41:	########################################	elapsed: 1.60s, accuracy: 96.49
# Epoch 42:	########################################	elapsed: 1.55s, accuracy: 96.49
# Epoch 43:	########################################	elapsed: 1.58s, accuracy: 96.48
# Epoch 44:	########################################	elapsed: 1.68s, accuracy: 96.49
# Epoch 45:	########################################	elapsed: 1.57s, accuracy: 96.50
# Epoch 46:	########################################	elapsed: 1.55s, accuracy: 96.50
# Epoch 47:	########################################	elapsed: 1.55s, accuracy: 96.48
# Epoch 48:	########################################	elapsed: 1.55s, accuracy: 96.47
# Epoch 49:	########################################	elapsed: 1.55s, accuracy: 96.47
# Epoch 50:	########################################	elapsed: 1.56s, accuracy: 96.47
# Training finished!
# <h3>Input layer filters in the plain MLP</h3>
# <h3>Largest norms of weight-vectors in the plain MLP layers</h3>
# 	layer 1: 2.00
# 	layer 2: 1.00
# 	layer 3: 0.70
# 	layer 4: 4.00
# <h3>DBN training</h3>
# Learning layer 1
# Epoch 1:	########################################	elapsed: 1.03s, reconstruction error: 79.39
# Epoch 2:	########################################	elapsed: 1.02s, reconstruction error: 56.96
# Epoch 3:	########################################	elapsed: 1.03s, reconstruction error: 44.35
# Epoch 4:	########################################	elapsed: 1.02s, reconstruction error: 37.67
# Epoch 5:	########################################	elapsed: 1.05s, reconstruction error: 33.66
# Epoch 6:	########################################	elapsed: 1.00s, reconstruction error: 25.50
# Epoch 7:	########################################	elapsed: 1.03s, reconstruction error: 21.82
# Epoch 8:	########################################	elapsed: 1.01s, reconstruction error: 19.49
# Epoch 9:	########################################	elapsed: 1.03s, reconstruction error: 17.77
# Epoch 10:	########################################	elapsed: 1.13s, reconstruction error: 16.70
# Epoch 11:	########################################	elapsed: 1.05s, reconstruction error: 15.51
# Epoch 12:	########################################	elapsed: 1.11s, reconstruction error: 14.68
# Epoch 13:	########################################	elapsed: 1.03s, reconstruction error: 14.17
# Epoch 14:	########################################	elapsed: 1.02s, reconstruction error: 13.51
# Epoch 15:	########################################	elapsed: 1.02s, reconstruction error: 13.00
# Epoch 16:	########################################	elapsed: 1.04s, reconstruction error: 12.53
# Epoch 17:	########################################	elapsed: 1.06s, reconstruction error: 12.09
# Epoch 18:	########################################	elapsed: 1.07s, reconstruction error: 11.65
# Epoch 19:	########################################	elapsed: 1.16s, reconstruction error: 11.53
# Epoch 20:	########################################	elapsed: 1.09s, reconstruction error: 11.25
# Epoch 21:	########################################	elapsed: 1.09s, reconstruction error: 11.02
# Epoch 22:	########################################	elapsed: 1.13s, reconstruction error: 10.74
# Epoch 23:	########################################	elapsed: 1.15s, reconstruction error: 10.66
# Epoch 24:	########################################	elapsed: 1.16s, reconstruction error: 10.55
# Epoch 25:	########################################	elapsed: 1.12s, reconstruction error: 10.28
# Epoch 26:	########################################	elapsed: 1.10s, reconstruction error: 10.22
# Epoch 27:	########################################	elapsed: 1.10s, reconstruction error: 10.06
# Epoch 28:	########################################	elapsed: 1.11s, reconstruction error: 9.94
# Epoch 29:	########################################	elapsed: 1.10s, reconstruction error: 9.96
# Epoch 30:	########################################	elapsed: 1.15s, reconstruction error: 9.87
# Epoch 31:	########################################	elapsed: 1.14s, reconstruction error: 9.86
# Epoch 32:	########################################	elapsed: 1.15s, reconstruction error: 9.72
# Epoch 33:	########################################	elapsed: 1.12s, reconstruction error: 9.72
# Epoch 34:	########################################	elapsed: 1.13s, reconstruction error: 9.58
# Epoch 35:	########################################	elapsed: 1.13s, reconstruction error: 9.62
# Epoch 36:	########################################	elapsed: 1.13s, reconstruction error: 9.39
# Epoch 37:	########################################	elapsed: 1.30s, reconstruction error: 9.53
# Epoch 38:	########################################	elapsed: 1.15s, reconstruction error: 9.39
# Epoch 39:	########################################	elapsed: 1.13s, reconstruction error: 9.57
# Epoch 40:	########################################	elapsed: 1.15s, reconstruction error: 9.42
# Epoch 41:	########################################	elapsed: 1.11s, reconstruction error: 9.29
# Epoch 42:	########################################	elapsed: 1.11s, reconstruction error: 9.37
# Epoch 43:	########################################	elapsed: 1.12s, reconstruction error: 9.38
# Epoch 44:	########################################	elapsed: 1.15s, reconstruction error: 9.27
# Epoch 45:	########################################	elapsed: 1.18s, reconstruction error: 9.34
# Epoch 46:	########################################	elapsed: 1.18s, reconstruction error: 9.35
# Epoch 47:	########################################	elapsed: 1.14s, reconstruction error: 9.28
# Epoch 48:	########################################	elapsed: 1.12s, reconstruction error: 9.18
# Epoch 49:	########################################	elapsed: 1.05s, reconstruction error: 9.18
# Epoch 50:	########################################	elapsed: 1.04s, reconstruction error: 9.20
#
# Learning layer 2
# Epoch 1:	########################################	elapsed: 0.84s, reconstruction error: 20.23
# Epoch 2:	########################################	elapsed: 0.85s, reconstruction error: 19.42
# Epoch 3:	########################################	elapsed: 0.92s, reconstruction error: 17.28
# Epoch 4:	########################################	elapsed: 0.95s, reconstruction error: 16.23
# Epoch 5:	########################################	elapsed: 0.96s, reconstruction error: 15.53
# Epoch 6:	########################################	elapsed: 0.95s, reconstruction error: 16.05
# Epoch 7:	########################################	elapsed: 0.93s, reconstruction error: 15.07
# Epoch 8:	########################################	elapsed: 0.94s, reconstruction error: 15.36
# Epoch 9:	########################################	elapsed: 0.91s, reconstruction error: 14.98
# Epoch 10:	########################################	elapsed: 0.93s, reconstruction error: 15.29
# Epoch 11:	########################################	elapsed: 0.92s, reconstruction error: 15.23
# Epoch 12:	########################################	elapsed: 0.92s, reconstruction error: 14.89
# Epoch 13:	########################################	elapsed: 0.92s, reconstruction error: 14.66
# Epoch 14:	########################################	elapsed: 0.92s, reconstruction error: 15.00
# Epoch 15:	########################################	elapsed: 0.92s, reconstruction error: 15.05
# Epoch 16:	########################################	elapsed: 0.95s, reconstruction error: 14.83
# Epoch 17:	########################################	elapsed: 0.91s, reconstruction error: 14.87
# Epoch 18:	########################################	elapsed: 0.89s, reconstruction error: 14.84
# Epoch 19:	########################################	elapsed: 0.89s, reconstruction error: 14.92
# Epoch 20:	########################################	elapsed: 0.89s, reconstruction error: 14.64
# Epoch 21:	########################################	elapsed: 0.89s, reconstruction error: 14.57
# Epoch 22:	########################################	elapsed: 0.89s, reconstruction error: 14.83
# Epoch 23:	########################################	elapsed: 0.91s, reconstruction error: 14.66
# Epoch 24:	########################################	elapsed: 0.90s, reconstruction error: 14.67
# Epoch 25:	########################################	elapsed: 0.90s, reconstruction error: 14.74
# Epoch 26:	########################################	elapsed: 0.89s, reconstruction error: 14.73
# Epoch 27:	########################################	elapsed: 0.90s, reconstruction error: 14.96
# Epoch 28:	########################################	elapsed: 0.90s, reconstruction error: 14.73
# Epoch 29:	########################################	elapsed: 0.90s, reconstruction error: 14.77
# Epoch 30:	########################################	elapsed: 0.90s, reconstruction error: 14.51
# Epoch 31:	########################################	elapsed: 0.90s, reconstruction error: 14.79
# Epoch 32:	########################################	elapsed: 0.90s, reconstruction error: 14.80
# Epoch 33:	########################################	elapsed: 0.90s, reconstruction error: 14.64
# Epoch 34:	########################################	elapsed: 0.90s, reconstruction error: 14.87
# Epoch 35:	########################################	elapsed: 0.89s, reconstruction error: 14.94
# Epoch 36:	########################################	elapsed: 0.90s, reconstruction error: 15.03
# Epoch 37:	########################################	elapsed: 0.90s, reconstruction error: 14.48
# Epoch 38:	########################################	elapsed: 0.90s, reconstruction error: 14.87
# Epoch 39:	########################################	elapsed: 0.90s, reconstruction error: 14.94
# Epoch 40:	########################################	elapsed: 0.91s, reconstruction error: 14.81
# Epoch 41:	########################################	elapsed: 0.90s, reconstruction error: 15.01
# Epoch 42:	########################################	elapsed: 0.92s, reconstruction error: 14.84
# Epoch 43:	########################################	elapsed: 0.91s, reconstruction error: 14.83
# Epoch 44:	########################################	elapsed: 0.85s, reconstruction error: 14.73
# Epoch 45:	########################################	elapsed: 0.85s, reconstruction error: 14.90
# Epoch 46:	########################################	elapsed: 0.84s, reconstruction error: 14.84
# Epoch 47:	########################################	elapsed: 0.84s, reconstruction error: 14.82
# Epoch 48:	########################################	elapsed: 0.83s, reconstruction error: 15.09
# Epoch 49:	########################################	elapsed: 0.87s, reconstruction error: 15.31
# Epoch 50:	########################################	elapsed: 0.95s, reconstruction error: 15.19
#
# Learning layer 3
# Epoch 1:	########################################	elapsed: 1.32s, reconstruction error: 7.02
# Epoch 2:	########################################	elapsed: 1.32s, reconstruction error: 6.38
# Epoch 3:	########################################	elapsed: 1.27s, reconstruction error: 5.96
# Epoch 4:	########################################	elapsed: 1.41s, reconstruction error: 5.69
# Epoch 5:	########################################	elapsed: 1.34s, reconstruction error: 5.46
# Epoch 6:	########################################	elapsed: 1.38s, reconstruction error: 5.92
# Epoch 7:	########################################	elapsed: 1.38s, reconstruction error: 5.84
# Epoch 8:	########################################	elapsed: 1.33s, reconstruction error: 5.60
# Epoch 9:	########################################	elapsed: 1.32s, reconstruction error: 5.57
# Epoch 10:	########################################	elapsed: 1.31s, reconstruction error: 5.37
# Epoch 11:	########################################	elapsed: 1.26s, reconstruction error: 5.35
# Epoch 12:	########################################	elapsed: 1.28s, reconstruction error: 5.10
# Epoch 13:	########################################	elapsed: 1.32s, reconstruction error: 5.07
# Epoch 14:	########################################	elapsed: 1.33s, reconstruction error: 4.84
# Epoch 15:	########################################	elapsed: 1.31s, reconstruction error: 4.82
# Epoch 16:	########################################	elapsed: 1.31s, reconstruction error: 4.75
# Epoch 17:	########################################	elapsed: 1.34s, reconstruction error: 4.65
# Epoch 18:	########################################	elapsed: 1.31s, reconstruction error: 4.64
# Epoch 19:	########################################	elapsed: 1.31s, reconstruction error: 4.48
# Epoch 20:	########################################	elapsed: 1.31s, reconstruction error: 4.35
# Epoch 21:	########################################	elapsed: 1.47s, reconstruction error: 4.35
# Epoch 22:	########################################	elapsed: 1.48s, reconstruction error: 4.37
# Epoch 23:	########################################	elapsed: 1.31s, reconstruction error: 4.33
# Epoch 24:	########################################	elapsed: 1.31s, reconstruction error: 4.33
# Epoch 25:	########################################	elapsed: 1.30s, reconstruction error: 4.27
# Epoch 26:	########################################	elapsed: 1.31s, reconstruction error: 4.27
# Epoch 27:	########################################	elapsed: 1.32s, reconstruction error: 4.33
# Epoch 28:	########################################	elapsed: 1.35s, reconstruction error: 4.27
# Epoch 29:	########################################	elapsed: 1.38s, reconstruction error: 4.31
# Epoch 30:	########################################	elapsed: 1.31s, reconstruction error: 4.33
# Epoch 31:	########################################	elapsed: 1.32s, reconstruction error: 4.33
# Epoch 32:	########################################	elapsed: 1.31s, reconstruction error: 4.32
# Epoch 33:	########################################	elapsed: 1.32s, reconstruction error: 4.27
# Epoch 34:	########################################	elapsed: 1.32s, reconstruction error: 4.30
# Epoch 35:	########################################	elapsed: 1.32s, reconstruction error: 4.32
# Epoch 36:	########################################	elapsed: 1.32s, reconstruction error: 4.35
# Epoch 37:	########################################	elapsed: 1.32s, reconstruction error: 4.30
# Epoch 38:	########################################	elapsed: 1.31s, reconstruction error: 4.34
# Epoch 39:	########################################	elapsed: 1.35s, reconstruction error: 4.30
# Epoch 40:	########################################	elapsed: 1.31s, reconstruction error: 4.35
# Epoch 41:	########################################	elapsed: 1.31s, reconstruction error: 4.30
# Epoch 42:	########################################	elapsed: 1.31s, reconstruction error: 4.31
# Epoch 43:	########################################	elapsed: 1.31s, reconstruction error: 4.29
# Epoch 44:	########################################	elapsed: 1.32s, reconstruction error: 4.23
# Epoch 45:	########################################	elapsed: 1.31s, reconstruction error: 4.25
# Epoch 46:	########################################	elapsed: 1.33s, reconstruction error: 4.27
# Epoch 47:	########################################	elapsed: 1.32s, reconstruction error: 4.29
# Epoch 48:	########################################	elapsed: 1.31s, reconstruction error: 4.28
# Epoch 49:	########################################	elapsed: 1.32s, reconstruction error: 4.24
# Epoch 50:	########################################	elapsed: 1.30s, reconstruction error: 4.28
# <h3>Finetuning pretrained MLP</h3>
# Epoch 1:	########################################	elapsed: 1.48s, accuracy: 90.07
# Epoch 2:	########################################	elapsed: 1.55s, accuracy: 94.19
# Epoch 3:	########################################	elapsed: 1.54s, accuracy: 95.41
# Epoch 4:	########################################	elapsed: 1.58s, accuracy: 94.76
# Epoch 5:	########################################	elapsed: 1.53s, accuracy: 94.90
# Epoch 6:	########################################	elapsed: 1.54s, accuracy: 95.22
# Epoch 7:	########################################	elapsed: 1.58s, accuracy: 93.98
# Epoch 8:	########################################	elapsed: 1.55s, accuracy: 94.58
# Epoch 9:	########################################	elapsed: 1.53s, accuracy: 94.94
# Epoch 10:	########################################	elapsed: 1.53s, accuracy: 96.01
# Epoch 11:	########################################	elapsed: 1.57s, accuracy: 95.63
# Epoch 12:	########################################	elapsed: 1.56s, accuracy: 95.03
# Epoch 13:	########################################	elapsed: 1.53s, accuracy: 95.43
# Epoch 14:	########################################	elapsed: 1.54s, accuracy: 95.76
# Epoch 15:	########################################	elapsed: 1.53s, accuracy: 95.90
# Epoch 16:	########################################	elapsed: 1.55s, accuracy: 96.40
# Epoch 17:	########################################	elapsed: 1.56s, accuracy: 96.55
# Epoch 18:	########################################	elapsed: 1.54s, accuracy: 95.74
# Epoch 19:	########################################	elapsed: 1.56s, accuracy: 95.73
# Epoch 20:	########################################	elapsed: 1.54s, accuracy: 96.58
# Epoch 21:	########################################	elapsed: 1.58s, accuracy: 96.14
# Epoch 22:	########################################	elapsed: 1.58s, accuracy: 96.72
# Epoch 23:	########################################	elapsed: 1.72s, accuracy: 96.81
# Epoch 24:	########################################	elapsed: 1.58s, accuracy: 96.78
# Epoch 25:	########################################	elapsed: 1.55s, accuracy: 96.81
# Epoch 26:	########################################	elapsed: 1.54s, accuracy: 96.79
# Epoch 27:	########################################	elapsed: 1.74s, accuracy: 96.63
# Epoch 28:	########################################	elapsed: 1.59s, accuracy: 96.87
# Epoch 29:	########################################	elapsed: 1.59s, accuracy: 96.92
# Epoch 30:	########################################	elapsed: 1.56s, accuracy: 97.11
# Epoch 31:	########################################	elapsed: 1.54s, accuracy: 96.89
# Epoch 32:	########################################	elapsed: 1.55s, accuracy: 96.65
# Epoch 33:	########################################	elapsed: 1.55s, accuracy: 97.09
# Epoch 34:	########################################	elapsed: 1.56s, accuracy: 97.14
# Epoch 35:	########################################	elapsed: 1.55s, accuracy: 97.14
# Epoch 36:	########################################	elapsed: 1.70s, accuracy: 97.14
# Epoch 37:	########################################	elapsed: 1.65s, accuracy: 97.14
# Epoch 38:	########################################	elapsed: 1.54s, accuracy: 97.11
# Epoch 39:	########################################	elapsed: 1.57s, accuracy: 97.11
# Epoch 40:	########################################	elapsed: 1.78s, accuracy: 97.11
# Epoch 41:	########################################	elapsed: 1.56s, accuracy: 97.11
# Epoch 42:	########################################	elapsed: 1.55s, accuracy: 97.11
# Epoch 43:	########################################	elapsed: 2.09s, accuracy: 97.11
# Epoch 44:	########################################	elapsed: 1.60s, accuracy: 97.12
# Epoch 45:	########################################	elapsed: 1.60s, accuracy: 97.12
# Epoch 46:	########################################	elapsed: 1.56s, accuracy: 97.12
# Epoch 47:	########################################	elapsed: 1.45s, accuracy: 97.12
# Epoch 48:	########################################	elapsed: 1.38s, accuracy: 97.12
# Epoch 49:	########################################	elapsed: 1.62s, accuracy: 97.12
# Epoch 50:	########################################	elapsed: 1.61s, accuracy: 97.12
# Training finished!
# <h3>First layer filters in the DBN</h3>
# <h3>Input layer filters in the pretrained & finetuned MLP</h3>
# <h3>Largest norms of weight-vectors in the finetuned MLP layers</h3>
# 	layer 1: 2.00
# 	layer 2: 1.00
# 	layer 3: 1.00
# 	layer 4: 4.00
